# %%
from IPython.display import display
import spot
from spot.jupyter import display_inline
spot.setup(show_default='.tvb')
from product import async_prod

# %%
# System specification
aut_sys = spot.translate('F(home) & G(!(empty))', 'Buchi', 'state-based', 'complete'); aut_sys.show("v")

# %%
# How to get rid of the redundant transition-based acceptance label from state 0 to 2?
print(aut_sys.to_str('hoa'))
# Out:
# HOA: v1
# States: 3
# Start: 1
# AP: 2 "home" "empty"
# acc-name: Buchi
# Acceptance: 1 Inf(0)
# properties: trans-labels explicit-labels state-acc complete
# properties: deterministic stutter-invariant very-weak
# --BODY--
# State: 0 {0}
# [!1] 0
# [1] 2
# State: 1
# [0&!1] 0
# [!0&!1] 1
# [1] 2
# State: 2
# [t] 2
# --END--

# %%
# Tester spec:
aut_test = spot.translate('F(refuel)', 'Buchi', 'state-based', 'complete'); aut_test.show("v")

# %%
aut_prod, states_prod = async_prod(aut_sys, aut_test); aut_prod.show("v")
# Out:
# [(1, 1, 0)]
# ----------------------------------
# new edge in todo: (1, 1, 0)
# [(0, 1, 1), (2, 1, 2), (1, 0, 3)]
# ----------------------------------
# new edge in todo: (1, 0, 3)
# [(0, 1, 1), (2, 1, 2), (0, 0, 4), (2, 0, 5)]
# ----------------------------------
# new edge in todo: (2, 0, 5)
# [(0, 1, 1), (2, 1, 2), (0, 0, 4)]
# ----------------------------------
# new edge in todo: (0, 0, 4)
# [(0, 1, 1), (2, 1, 2)]
# ----------------------------------
# new edge in todo: (2, 1, 2)
# [(0, 1, 1)]
# ----------------------------------
# new edge in todo: (0, 1, 1)

# %%
# Patrolling car asynchronous product automaton:
a_sys = spot.translate('F(park & F(home))', 'Buchi', 'state-based', 'complete')
a_test = spot.translate(' G(park -> F(refuel))', 'Buchi', 'state-based', 'complete')
a_sync_prod = spot.product(a_sys, a_test); a_sync_prod
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x10b1f3cc0> >

# %%
a_async_prod, states = async_prod(a_sys, a_test)
a_async_prod
# Out:
# [(1, 0, 0)]
# ----------------------------------
# new edge in todo: (1, 0, 0)
# [(0, 0, 1), (2, 0, 2), (1, 1, 3)]
# ----------------------------------
# new edge in todo: (1, 1, 3)
# [(0, 0, 1), (2, 0, 2), (0, 1, 4), (2, 1, 5)]
# ----------------------------------
# new edge in todo: (2, 1, 5)
# [(0, 0, 1), (2, 0, 2), (0, 1, 4)]
# ----------------------------------
# new edge in todo: (0, 1, 4)
# [(0, 0, 1), (2, 0, 2)]
# ----------------------------------
# new edge in todo: (2, 0, 2)
# [(0, 0, 1)]
# ----------------------------------
# new edge in todo: (0, 0, 1)
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x10b1f3180> >
